# %% [markdown]
# # My primary aim of using this notebook is to write down the python code for the capstone project.  <a id="0"></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
